# %% [markdown]
# ## 使用梯度下降的方法计算泰勒级数
#
# ### 在迭代10000次后产生梯度弥散，无法进一步优化参数

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
 
# Create random input and output data
x = np.linspace(-math.pi, math.pi, 2000)
y = np.sin(x)
plt.plot(x,y)
plt.show()
 
# Randomly initialize weights
a = np.random.randn()
b = np.random.randn()
c = np.random.randn()
d = np.random.randn()
learning_rate = 1e-6
 
for t in range(40000):
    # Forward pass: compute predicted y
    # y = a + b x + c x^2 + d x^3
    y_pred = a + b * x + c * x**2 + d * x**3
 
    # Compute and print loss
    loss = np.square(y_pred - y).sum()
 
    if t % 500 == 99:
        print(t, loss)
 
    # Backprop to compute gradients of a, b, c, d with respect to loss
    grad_y_pred = 2.0 * (y_pred - y)
    grad_a = grad_y_pred.sum()
    grad_b = (grad_y_pred * x).sum()
    grad_c = (grad_y_pred * x**2).sum()
    grad_d = (grad_y_pred * x**3).sum()
 
    # Update weights
    a -= learning_rate * grad_a
    b -= learning_rate * grad_b
    c -= learning_rate * grad_c
    d -= learning_rate * grad_d
 
print(f'Result: y = {a} + {b} x + {c} x^2 + {d} x^3')
# Out:
# 99 35.21585229352782
# 599 12.222853718711725
# 1099 9.259842447110344
# 1599 8.875280569156914
# 2099 8.824894129414428
# 2599 8.818210219284353
# 3099 8.817309515557785
# 3599 8.817185760894324
# 4099 8.817168361283544
# 4599 8.817165850277355
# 5099 8.817165477585814
# 5599 8.817165420665614
# 6099 8.817165411729862
# 6599 8.817165410291441
# 7099 8.817165410054802
# 7599 8.81716541001516
# 8099 8.817165410008425
# 8599 8.81716541000727
# 9099 8.817165410007068
# 9599 8.817165410007032
# 10099 8.817165410007028
# 10599 8.817165410007025
# 11099 8.817165410007025
# 11599 8.817165410007025
# 12099 8.817165410007025
# 12599 8.817165410007023
# 13099 8.817165410007025
# 13599 8.817165410007025
# 14099 8.817165410007025
# 14599 8.817165410007027
# 15099 8.817165410007025
# 15599 8.817165410007027
# 16099 8.817165410007027
# 16599 8.817165410007025
# 17099 8.817165410007025
# 17599 8.817165410007025
# 18099 8.817165410007025
# 18599 8.817165410007027
# 19099 8.817165410007027
# 19599 8.817165410007025
# 20099 8.817165410007027
# 20599 8.817165410007027
# 21099 8.817165410007025
# 21599 8.817165410007025
# 22099 8.817165410007025
# 22599 8.817165410007025
# 23099 8.817165410007025
# 23599 8.817165410007025
# 24099 8.817165410007025
# 24599 8.817165410007025
# 25099 8.817165410007025
# 25599 8.817165410007025
# 26099 8.817165410007025
# 26599 8.817165410007025
# 27099 8.817165410007025
# 27599 8.817165410007025
# 28099 8.817165410007025
# 28599 8.817165410007025
# 29099 8.817165410007025
# 29599 8.817165410007025
# 30099 8.817165410007025
# 30599 8.817165410007025
# 31099 8.817165410007025
# 31599 8.817165410007025
# 32099 8.817165410007025
# 32599 8.817165410007025
# 33099 8.817165410007025
# 33599 8.817165410007025
# 34099 8.817165410007025
# 34599 8.817165410007025
# 35099 8.817165410007025
# 35599 8.817165410007025
# 36099 8.817165410007025
# 36599 8.817165410007025
# 37099 8.817165410007025
# 37599 8.817165410007025
# 38099 8.817165410007025
# 38599 8.817165410007025
# 39099 8.817165410007025
# 39599 8.817165410007025
# Result: y = -1.3880583676844463e-17 + 0.8567408430738108 x + 2.1341790938431817e-17 x^2 + -0.09333038904060259 x^3

# %%
print(a,b,c,d)
plt.plot(x,y)
plt.plot(x,y_pred)
plt.legend(['y','y_pred'])
# Out:
# -1.3880583676844463e-17 0.8567408430738108 2.1341790938431817e-17 -0.09333038904060259
